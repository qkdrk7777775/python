# %% [markdown]
# https://github.com/pycaret/pycaret/tree/master/examples

# %%
import pycaret

# %%
pycaret.__version__
# Out:
# '2.2.0'

# %%
from pycaret.utils import version
version()
# Out:
# '2.2.1'

# %%
from pycaret.datasets import get_data
index=get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data=get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *
clf1 = setup(data, target='Purchase', session_id=123, 
             log_experiment=True, experiment_name='exam_juice')
# Out:
# <style  type="text/css" >
# #T_1a6cf5f6_2aed_11eb_a250_7085c2af116drow19_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_1a6cf5f6_2aed_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a6cf5f6_2aed_11eb_a250_7085c2af116dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1a6cf5f6_2aed_11eb_a250_7085c2af116drow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1a6cf5f6_2aed_11eb_a250_7085c2af116drow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_1a6cf5f6_2aed_11eb_a250_7085c2af116dlevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
dir(pycaret.classification)
# Out:
# ['Any',
#  'Dict',
#  'Display',
#  'List',
#  'MLUsecase',
#  'Optional',
#  'Tuple',
#  'Union',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add_metric',
#  'automl',
#  'blend_models',
#  'calibrate_model',
#  'compare_models',
#  'create_model',
#  'deploy_model',
#  'enable_colab',
#  'ensemble_model',
#  'evaluate_model',
#  'finalize_model',
#  'get_config',
#  'get_logs',
#  'get_metrics',
#  'interpret_model',
#  'io',
#  'is_in_colab',
#  'load_config',
#  'load_model',
#  'models',
#  'np',
#  'optimize_threshold',
#  'pd',
#  'plot_model',
#  'predict_model',
#  'pull',
#  'pycaret',
#  'remove_metric',
#  'save_config',
#  'save_model',
#  'set_config',
#  'setup',
#  'stack_models',
#  'traceback',
#  'tune_model',
#  'warnings']

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_6d7e2df0_2aed_11eb_a250_7085c2af116d th {
#           text-align: left;
# ...

# %%
lr = create_model('lr')
tuned_lr = tune_model(lr)
# Out:
# <style  type="text/css" >
# #T_89489c86_2aee_11eb_a250_7085c2af116drow10_col0,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col1,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col2,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col3,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col4,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col5,#T_89489c86_2aee_11eb_a250_7085c2af116drow10_col6{
#             background:  yellow;
#         }</style><table id="T_89489c86_2aee_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
dt = create_model('dt')
bagged_dt = ensemble_model(dt) # 배깅
boosted_dt = ensemble_model(dt, method='Boosting') # 부스팅
# Out:
# <style  type="text/css" >
# #T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col0,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col1,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col2,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col3,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col4,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col5,#T_9d077b3e_2aee_11eb_a250_7085c2af116drow10_col6{
#             background:  yellow;
#         }</style><table id="T_9d077b3e_2aee_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
blender = blend_models(estimator_list= 
                       [boosted_dt, bagged_dt, tuned_lr], method='soft')
# Out:
# <style  type="text/css" >
# #T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col0,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col1,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col2,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col3,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col4,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col5,#T_b25556aa_2aee_11eb_a250_7085c2af116drow10_col6{
#             background:  yellow;
#         }</style><table id="T_b25556aa_2aee_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
rf = create_model('rf', fold = 5)
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
# #T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col0,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col1,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col2,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col3,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col4,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col5,#T_8ff99390_2aef_11eb_a250_7085c2af116drow10_col6{
#             background:  yellow;
#         }</style><table id="T_8ff99390_2aef_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
stacker = stack_models(estimator_list=
                       [boosted_dt, bagged_dt, tuned_rf], meta_model=rf)
# Out:
# <style  type="text/css" >
# #T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col0,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col1,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col2,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col3,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col4,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col5,#T_a41789cc_2aef_11eb_a250_7085c2af116drow10_col6{
#             background:  yellow;
#         }</style><table id="T_a41789cc_2aef_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(rf)

# %%
plot_model(stacker)

# %%
plot_model(rf, plot = 'boundary')

# %%
plot_model(rf, plot = 'feature')

# %%
plot_model(rf, plot = 'class_report')

# %%
rf = create_model('rf', cross_validation=False)
interpret_model(rf)
# Out:
#    Accuracy    AUC  Recall   Prec.      F1  Kappa     MCC
# 0     0.795  0.863  0.7154  0.7623  0.7381   0.57  0.5708

# %%
lightgbm = create_model('lightgbm', cross_validation = False)
interpret_model(lightgbm)
# Out:
#    Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0    0.7919  0.8774  0.7231  0.752  0.7373  0.5651  0.5654

# %%
et=create_model('et', cross_validation = False)
interpret_model(et)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0    0.7981  0.8408  0.7231  0.7642  0.7431  0.5771  0.5777

# %%
catboost=create_model('catboost', cross_validation = False)
interpret_model(catboost)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0     0.823  0.8979  0.7231  0.8174  0.7673  0.6254  0.6284

# %%
best = automl(optimize = 'Recall')
best
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
pred_holdouts = predict_model(best)
pred_holdouts.head()
# Out:
# <style  type="text/css" >
# </style><table id="T_2c3a946a_2af1_11eb_a250_7085c2af116d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2c3a946a_2af1_11eb_a250_7085c2af116dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2c3a946a_2af1_11eb_a250_7085c2af116drow0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
# ...
